# %%
#Tuple is Immutable . No further changes can be made to it after its creation.

# %%
#Creation of the tuple 
tpl=()
tpl1=tuple()
print(tpl,tpl1)

tpll=(1)
print(type(tpll))

tp=1,2,3,4,"move",9  # Also without the paranthesis it will be considerd as tuple
print(type(tp))

#Single element of the tuple cannot be deleted we need to delete the whole tuplw using the 'del' keyword
tplll=(1)
del tplll  # if we try to print it after its
# Out:
# () ()
# <class 'int'>
# <class 'tuple'>

# %%
#Making changes in the tuple first convert the tuple in the into , make the nescessary changes then again convert into tuple  

tpl = (2,3,4,"hello")
tpl=list(tpl)
tpl[3]=90
tpl=tuple(tpl)
print(tpl)
# Out:
# (2, 3, 4, 90)

# %%
#Count Method
tpl = (2,3,4,4,5)
tpl.count(4)
# Out:
# 2

# %%
#Sorted Method
tpl = (2,3,4,4,5,77,8,9,76)
print(sorted(tpl,reverse=True))  #reverse will give it in the desending order
# Out:
# [77, 76, 9, 8, 5, 4, 4, 3, 2]
