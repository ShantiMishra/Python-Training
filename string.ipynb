# %%
#String is immutable 
mystring = "hii"
print(mystring)

# %%
#concatenation of 2 strings 
s1="Shanti"
s2="Mishra"
s1=s1+s2
print(s1)

s=s1*3
print(s)

# %%
print('o' in "hello world")
print('o' not in "hello world")

# %%
x="hello"
y=x.lower()
print(y)

a="Hello Jennie".capitalize()

# %%
str="hello user I - am learning python"
lst=str.split(sep='-') #separate with the ,
t=" ".join(str) #join method

# %%
#Replace 
str="I eat apple"
str2=str.replace("apple","banana")

# %%
text="apple,banana.apple,cherry,apple."
str=text.replace()
